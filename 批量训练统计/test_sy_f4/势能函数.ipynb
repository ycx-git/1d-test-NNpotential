# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %%
def fun1(x):
    return 2*x**2

# %%
def fun2(x):
    return x*torch.sin(torch.pi*x/2.5)*10+x**4/25

# %%
def fun3(x):
    f=x*torch.sin(torch.pi*x)+x**2*2
    return f

# %%
def fun4(x):
    f=(x-5)**2*(x+5)**2/25
    return f

# %%
def fun5(x):
    f=x*torch.sin(torch.pi*x*2/3)+x**2*2
    return f

# %%
def fun6(x):
    f=x*torch.sin(torch.pi*x*2/3)+x**2*2
    return f

# %%
def fun7(x):
    f=(x/2+torch.sin(x*torch.pi/5))**2*8
    return f

# %%
def fun8(x):
    f=(x*5/6+torch.sin(x*torch.pi*3/8))**2*3
    return f

# %%
x=torch.linspace(-10, 10, 1000)
f1=fun1(x)
f2=fun2(x)
f3=fun3(x)
f4=fun4(x)
f5=fun5(x)
f6=fun6(x)
f7=fun7(x)
f8=fun8(x)

# %%
# f3 0.02 40 
# f5 0.04 40

# %%
def pro(V,E):
    return 1/torch.sqrt(2*(E-V))
pro=pro(f4,65)

# %%
# plt.plot(x, f1, label='f1')
plt.plot(x, f4, label='f2')
plt.legend()
plt.show()

# %%
plt.plot(x, pro, label='pro')
plt.legend()
plt.show()
