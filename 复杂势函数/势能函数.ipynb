# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %%
def fun1(x):
    return 2*x**2

# %%
def fun2(x):
    return x*torch.sin(torch.pi*x/2.5)*10+x**4/25

# %%
def fun3(x):
    f=x*torch.sin(torch.pi*x)+x**2*2
    return f

# %%
def fun4(x):
    f=(x-5)**2*(x+5)**2/25
    return f

# %%
def fun5(x):
    f=2*x*torch.sin(torch.pi*x)+x**2*2
    return f

# %%
def fun6(x):
    f=3*x*torch.sin(torch.pi*x*2/3)+x**2*2
    return f

# %%
x=torch.linspace(-10, 10, 1000)
f1=fun1(x)
f2=fun2(x)
f3=fun3(x)
f4=fun4(x)
f5=fun5(x)
f6=fun6(x)

# %%
# plt.plot(x, f1, label='f1')
plt.plot(x, f2, label='f2')
plt.legend()
plt.show()
